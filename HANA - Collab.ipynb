# %%
# !git clone https://github.com/funabab/HANA.git
# Out:
# Cloning into 'HANA'...
# remote: Enumerating objects: 327, done.
# remote: Total 327 (delta 0), reused 0 (delta 0), pack-reused 327
# Receiving objects: 100% (327/327), 91.42 KiB | 1.90 MiB/s, done.
# Resolving deltas: 100% (201/201), done.

# %%
# !pip install kaggle --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir -p HANA/models HANA/datasets

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'KAGGLE_USERNAME'
os.environ['KAGGLE_KEY'] = 'KAGGLE_KEY'

# %%
# !kaggle datasets download sdusimonwittrock/danish-census-handwritten-names-small -p HANA/datasets
# Out:
# ...
#  81% 95.0M/117M [00:00<00:00, 190MB/s]
# 100% 117M/117M [00:00<00:00, 180MB/s]

# %%
# !unzip -d HANA/datasets HANA/datasets/danish-census-handwritten-names-small.zip
# !rm HANA/datasets/danish-census-handwritten-names-small.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: HANA/datasets/minipics/name-25/12955013.jpg
#   inflating: HANA/datasets/minipics/name-25/12957118.jpg
#   inflating: HANA/datasets/minipics/name-25/12957245.jpg
#   inflating: HANA/datasets/minipics/name-25/12957329.jpg
#   inflating: HANA/datasets/minipics/name-25/12958399.jpg
#   inflating: HANA/datasets/minipics/name-25/12958708.jpg
#   inflating: HANA/datasets/minipics/name-25/12958794.jpg
#   inflating: HANA/datasets/minipics/name-25/12960549.jpg
#   inflating: HANA/datasets/minipics/name-25/12963471.jpg
#   inflating: HANA/datasets/minipics/name-25/12963496.jpg
#   inflating: HANA/datasets/minipics/name-25/12964878.jpg
#   inflating: HANA/datasets/minipics/name-25/12964884.jpg
#   inflating: HANA/datasets/minipics/name-25/12972221.jpg
#   inflating: HANA/datasets/minipics/name-25/12972308.jpg
#   inflating: HANA/datasets/minipics/name-25/12972340.jpg
#   inflating: HANA/datasets/minipics/name-25/12972341.jpg
# ...

# %%
# !pip install numpy pandas pillow scikit-learn tensorboard setuptools==58
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.3/816.3 kB 14.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# arviz 0.15.1 requires setuptools>=60.0.0, but you have setuptools 58.0.0 which is incompatible.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 58.0.0 which is incompatible.
# ...

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !cd HANA && python evaluate.py --settings danish-census-small-last-name --root ./models --datadir ./datasets --model-from-url https://www.dropbox.com/s/i2jjk905vrcc4op/danish-census-small-last-name.pt?dl=1
# Out:
# Initializing model(s).
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:01<00:00, 87.9MB/s]
# Downloading: "https://www.dropbox.com/s/i2jjk905vrcc4op/danish-census-small-last-name.pt?dl=1" to /root/.cache/torch/hub/checkpoints/danish-census-small-last-name.pt
# 100% 102M/102M [00:00<00:00, 112MB/s]
# Initializing generator.
# Dropped 0 observations due to bad labels.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Predicting on test data!
# ...
